# %% [markdown]
# <a href="https://colab.research.google.com/github/a01731053-sys/Extraci-n-de-datos-/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
